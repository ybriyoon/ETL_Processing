# %%
import spotipy
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
CLIENT_ID = "3254c90a45084464a6d23b2466846bba"
CLIENT_SECRET = "46aa5be5e51647fb853a62d3e284cb22"
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}
headers
# Out:
# {'Authorization': 'Bearer BQAPrP02Tfzz__7pjZcZ0YTmEEZ7KFVoRIXyKlEp_2dbVL5nAAkgpyKYyY2BgGye48avGuGwCX8maOLi5OE'}

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/playlists/'

# Playlist ID from the URI
playlist_id = "37i9dQZF1DXcz8eC5kMSWZ"

# actual GET request with proper header
results = requests.get(BASE_URL + playlist_id + '/tracks', headers=headers)

# %%
top_99_data = results.json()

# %%
top_99_df_items =json_normalize(top_99_data['items'])
# Out:
# <ipython-input-6-02b68ef32dd0>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   top_99_df_items =json_normalize(top_99_data['items'])

# %%
pd.set_option('display.max_columns', None)
top_99_df_items.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2019-12-03T04:18:22Z     False          None
# 1  2019-12-03T04:18:22Z     False          None
# 2  2019-12-03T04:18:22Z     False          None
# 3  2019-12-03T04:18:22Z     False          None
# 4  2019-12-03T04:18:22Z     False          None
#
#    added_by.external_urls.spotify                      added_by.href  \
# 0  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 1  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 2  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 3  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 4  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
#
#   added_by.id added_by.type   added_by.uri track.album.album_type  \
# 0                      user  spotify:user:                  album
# 1                      user  spotify:user:                  album
# ...

# %%
top_99_df_items.shape
# Out:
# (50, 40)

# %%
top_99_data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Shawn Mendes'

# %%
artists = []
for i in top_99_data['items']:
    artists.append(i['track']['artists'][0]['name'])

top_99_df_items['artists'] = artists

# %%
top_99_df_items = top_99_df_items[['track.album.album_type',
       'track.album.id', 'track.album.name',
       'track.album.release_date',
       'track.duration_ms', 'track.explicit',
       'track.id', 'track.name', 'artists']]
top_99_df_items
# Out:
#    track.album.album_type          track.album.id  \
# 0                   album  0xzScN8P3hQAz3BT3YYX5w
# 1                   album  0S0KGZnfBGSIssfF54WSJh
# 2                   album  4g1ZRSobMefqF6nelkgibi
# 3                   album  2fYhqwDWXjbpjaIJPEfKFw
# 4                  single  4IRiXE5NROxknUSAUSjMoO
# 5                   album  3oIFxDIo2fwuk4lwCmFZCx
# 6                   album  4g1ZRSobMefqF6nelkgibi
# 7                   album  5658aM19fA3JVwTK6eQX70
# 8                  single  1otwHKoQ5KPaiekpYk4tWh
# 9                   album  4sLtOBOzn4s3GDUv3c5oJD
# 10                 single  78EicdHZr5XBWD7llEZ1Jh
# 11                 single  0zzrCTzvL4ZmR42xF46Afm
# 12                 single  1tFnP9PwIMeMIuj92mfswZ
# 13                  album  2fYhqwDWXjbpjaIJPEfKFw
# 14                  album  1Uf67JAtkVWfdydzFFqNF2
# 15                 single  7CdLU3GgPy1PH5FVsrPlyA
# 16                 single  1V9oE8bVilClrk5naqyyvL
# 17                  album  0S0KGZnfBGSIssfF54WSJh
# ...

# %%
top_99_df_items.rename(columns={'track.album.album_type': 'album_type', 'track.album.id': 'album_id', 
    'track.album.name': 'album_name', 'track.album.release_date': 'album_release_date', 
    'track.duration_ms': 'duration_ms', 'track.explicit': 'explicit', 'track.id': 'track_id',
    'track.name': 'track_name'}, inplace=True)
top_99_df_items.head()
# Out:
#   album_type                album_id  \
# 0      album  0xzScN8P3hQAz3BT3YYX5w
# 1      album  0S0KGZnfBGSIssfF54WSJh
# 2      album  4g1ZRSobMefqF6nelkgibi
# 3      album  2fYhqwDWXjbpjaIJPEfKFw
# 4     single  4IRiXE5NROxknUSAUSjMoO
#
#                                  album_name album_release_date  duration_ms  \
# 0                     Shawn Mendes (Deluxe)         2019-06-19       190799
# 1  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?         2019-03-29       194087
# 2                      Hollywood's Bleeding         2019-09-06       157560
# 3                             thank u, next         2019-02-08       178626
# 4                                      7 EP         2019-06-21       157066
#
#    explicit                track_id  \
# 0     False  6v3KW9xbzN5yKLt9YKDYA2
# 1     False  2Fxmhks0bxGSBdJ92vM42m
# 2     False  0RiRZpuVRbi7oqRdSMwhQY
# 3      True  6ocbgoVGwYJhOv1GgI9NsF
# 4     False  2YpeDb67231RjR0MgVLzsG
#
# ...

# %%
billboard_file = "billboard.csv"
billboard_df = pd.read_csv(billboard_file, encoding="ISO-8859-1")

# %%
billboard_df.head()
# Out:
#    Unnamed: 0                       artists           name  weekly_rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    peak_position  weeks_on_chart      week       date  \
# 0            1.0             7.0  7/6/2019   5-Apr-19
# 1            NaN             NaN  7/6/2019  21-Jun-19
# 2            2.0            13.0  7/6/2019  29-Mar-19
# 3            3.0            20.0  7/6/2019   7-Feb-19
# 4            2.0             7.0  7/6/2019  10-May-19
#
#                                                genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1                                                Pop
# ...

# %%
billboard_df = billboard_df[['artists', 'name', 'weekly_rank', 'peak_position', 'weeks_on_chart', 'week', 'date', 'genre', 'writing_credits', 'features']].copy()
billboard_df.head()
# Out:
#                         artists           name  weekly_rank  peak_position  \
# 0                      Lil Nas,  Old Town Road            1            1.0
# 1  Shawn Mendes, Camila Cabello       Senorita            2            NaN
# 2                 Billie Eilish        Bad Guy            3            2.0
# 3                        Khalid           Talk            4            3.0
# 4     Ed Sheeran, Justin Bieber   I Don't Care            5            2.0
#
#    weeks_on_chart      week       date  \
# 0             7.0  7/6/2019   5-Apr-19
# 1             NaN  7/6/2019  21-Jun-19
# 2            13.0  7/6/2019  29-Mar-19
# 3            20.0  7/6/2019   7-Feb-19
# 4             7.0  7/6/2019  10-May-19
#
#                                                genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1                                                Pop
# 2  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 3                                      Synth-Pop,Pop
# ...

# %%
from sqlalchemy import create_engine
rds_connection_string = "postgres:Elvis727@localhost:5432/etl-team3"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['billboard', 'spotify']

# %%
top_99_df_items.to_sql(name='spotify', con=engine, if_exists='append', index=False)
billboard_df.to_sql(name='billboard', con=engine, if_exists='append', index=False)

# %%
# 3. Export spotify and billboard dfs to sql tables
# 4. Join Spotify and Billboard tables
