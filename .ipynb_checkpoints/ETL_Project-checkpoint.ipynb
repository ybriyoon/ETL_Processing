# %%
import spotipy
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
CLIENT_ID = "3254c90a45084464a6d23b2466846bba"
CLIENT_SECRET = "46aa5be5e51647fb853a62d3e284cb22"
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']
# Out:
# 'BQDIBAq9fo0nzu8ZPcltqvJXlBBp21bJyJ4gYOV5OYrXzE0jIs4oB9wqPv5fwNN_EeCH7P5vscSVuwIdDDE'

# %%
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}
headers
# Out:
# {'Authorization': 'Bearer BQDIBAq9fo0nzu8ZPcltqvJXlBBp21bJyJ4gYOV5OYrXzE0jIs4oB9wqPv5fwNN_EeCH7P5vscSVuwIdDDE'}

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/playlists/'

# Playlist ID from the URI
playlist_id = "7fgURfzNGZG5OEzQfFqYUF"

# actual GET request with proper header
results = requests.get(BASE_URL + playlist_id + '/tracks', headers=headers)

# %%
top_99_data = results.json()
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/7fgURfzNGZG5OEzQfFqYUF/tracks?offset=0&limit=100',
#  'items': [{'added_at': '2011-08-17T05:56:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72OaDtakiy6yFqkt4TsiFt'},
#        'href': 'https://api.spotify.com/v1/artists/72OaDtakiy6yFqkt4TsiFt',
#        'id': '72OaDtakiy6yFqkt4TsiFt',
#        'name': 'Cher',
#        'type': 'artist',
#        'uri': 'spotify:artist:72OaDtakiy6yFqkt4TsiFt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0jZfbz0dNfDjPSg0hYJNth'},
#      'href': 'https://api.spotify.com/v1/albums/0jZfbz0dNfDjPSg0hYJNth',
#      'id': '0jZfbz0dNfDjPSg0hYJNth',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27361c83e0a3e42be611729c840',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0261c83e0a3e42be611729c840',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485161c83e0a3e42be611729c840',
#        'width': 64}],
#      'name': 'Believe',
#      'release_date': '1998',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:0jZfbz0dNfDjPSg0hYJNth'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72OaDtakiy6yFqkt4TsiFt'},
#       'href': 'https://api.spotify.com/v1/artists/72OaDtakiy6yFqkt4TsiFt',
#       'id': '72OaDtakiy6yFqkt4TsiFt',
#       'name': 'Cher',
#       'type': 'artist',
#       'uri': 'spotify:artist:72OaDtakiy6yFqkt4TsiFt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 239026,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHT9803002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2goLsvvODILDzeeiT4dAoR'},
#     'href': 'https://api.spotify.com/v1/tracks/2goLsvvODILDzeeiT4dAoR',
#     'id': '2goLsvvODILDzeeiT4dAoR',
#     'is_local': False,
#     'name': 'Believe',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/579967c91dc409b693b9819c12bbba83e4d0f9a4?cid=3254c90a45084464a6d23b2466846bba',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2goLsvvODILDzeeiT4dAoR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:56:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TImkz4nPqjegtVSMZnMRq'},
#        'href': 'https://api.spotify.com/v1/artists/0TImkz4nPqjegtVSMZnMRq',
#        'id': '0TImkz4nPqjegtVSMZnMRq',
#        'name': 'TLC',
#        'type': 'artist',
#        'uri': 'spotify:artist:0TImkz4nPqjegtVSMZnMRq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1CvjjpvqVMoyprsf74bpYW'},
#      'href': 'https://api.spotify.com/v1/albums/1CvjjpvqVMoyprsf74bpYW',
#      'id': '1CvjjpvqVMoyprsf74bpYW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27361ffafd5e31a37336531cf95',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0261ffafd5e31a37336531cf95',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485161ffafd5e31a37336531cf95',
#        'width': 64}],
#      'name': 'Fanmail',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:1CvjjpvqVMoyprsf74bpYW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TImkz4nPqjegtVSMZnMRq'},
#       'href': 'https://api.spotify.com/v1/artists/0TImkz4nPqjegtVSMZnMRq',
#       'id': '0TImkz4nPqjegtVSMZnMRq',
#       'name': 'TLC',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TImkz4nPqjegtVSMZnMRq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 214400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLF29900479'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1KGi9sZVMeszgZOWivFpxs'},
#     'href': 'https://api.spotify.com/v1/tracks/1KGi9sZVMeszgZOWivFpxs',
#     'id': '1KGi9sZVMeszgZOWivFpxs',
#     'is_local': False,
#     'name': 'No Scrubs',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/69daa711bddd8fe7aa9acf17106ca85cf1ccfa14?cid=3254c90a45084464a6d23b2466846bba',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:1KGi9sZVMeszgZOWivFpxs'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:57:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#        'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#        'id': '6XpaIBNiVzIetEPCWDvAFP',
#        'name': 'Whitney Houston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4bXTYQ8nVBYO4k3C3TOVri'},
#      'href': 'https://api.spotify.com/v1/albums/4bXTYQ8nVBYO4k3C3TOVri',
#      'id': '4bXTYQ8nVBYO4k3C3TOVri',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273989694c579cc8a29f99b6eda',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02989694c579cc8a29f99b6eda',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851989694c579cc8a29f99b6eda',
#        'width': 64}],
#      'name': 'Whitney The Greatest Hits',
#      'release_date': '2000-05-16',
#      'release_date_precision': 'day',
#      'total_tracks': 36,
#      'type': 'album',
#      'uri': 'spotify:album:4bXTYQ8nVBYO4k3C3TOVri'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#       'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#       'id': '6XpaIBNiVzIetEPCWDvAFP',
#       'name': 'Whitney Houston',
#       'type': 'artist',
#       'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5NDMothbpdpq2xHqSjrrWn'},
#       'href': 'https://api.spotify.com/v1/artists/5NDMothbpdpq2xHqSjrrWn',
#       'id': '5NDMothbpdpq2xHqSjrrWn',
#       'name': 'Faith Evans',
#       'type': 'artist',
#       'uri': 'spotify:artist:5NDMothbpdpq2xHqSjrrWn'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/49FeZO3eSrJs7oH7lYLU1r'},
#       'href': 'https://api.spotify.com/v1/artists/49FeZO3eSrJs7oH7lYLU1r',
#       'id': '49FeZO3eSrJs7oH7lYLU1r',
#       'name': 'Kelly Price',
#       'type': 'artist',
#       'uri': 'spotify:artist:49FeZO3eSrJs7oH7lYLU1r'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 245266,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAR19800139'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3EIzVtVW78E6qJqYTa0WUx'},
#     'href': 'https://api.spotify.com/v1/tracks/3EIzVtVW78E6qJqYTa0WUx',
#     'id': '3EIzVtVW78E6qJqYTa0WUx',
#     'is_local': False,
#     'name': 'Heartbreak Hotel (feat. Faith Evans & Kelly Price)',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:3EIzVtVW78E6qJqYTa0WUx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:57:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7e2tD25UffSO1019rrrRPe'},
#      'href': 'https://api.spotify.com/v1/albums/7e2tD25UffSO1019rrrRPe',
#      'id': '7e2tD25UffSO1019rrrRPe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735807b038488220ab49598ef9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025807b038488220ab49598ef9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515807b038488220ab49598ef9',
#        'width': 64}],
#      'name': 'Baby One More Time',
#      'release_date': '1999-01-12',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:7e2tD25UffSO1019rrrRPe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 210706,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI19810404'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7KIfxh9R4sxkPkn19ikdGd'},
#     'href': 'https://api.spotify.com/v1/tracks/7KIfxh9R4sxkPkn19ikdGd',
#     'id': '7KIfxh9R4sxkPkn19ikdGd',
#     'is_local': False,
#     'name': '...Baby One More Time',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7KIfxh9R4sxkPkn19ikdGd'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:57:29Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lJlKQvuM2Sd9DPPyUXcHg'},
#        'href': 'https://api.spotify.com/v1/artists/0lJlKQvuM2Sd9DPPyUXcHg',
#        'id': '0lJlKQvuM2Sd9DPPyUXcHg',
#        'name': 'Sixpence None The Richer',
#        'type': 'artist',
#        'uri': 'spotify:artist:0lJlKQvuM2Sd9DPPyUXcHg'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6HGNrA7twXCXBRQ2Rvc0kS'},
#      'href': 'https://api.spotify.com/v1/albums/6HGNrA7twXCXBRQ2Rvc0kS',
#      'id': '6HGNrA7twXCXBRQ2Rvc0kS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273983f594ce5c3bd6d5140e44c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02983f594ce5c3bd6d5140e44c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851983f594ce5c3bd6d5140e44c',
#        'width': 64}],
#      'name': 'Sixpence None The Richer',
#      'release_date': '1997',
#      'release_date_precision': 'year',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:6HGNrA7twXCXBRQ2Rvc0kS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lJlKQvuM2Sd9DPPyUXcHg'},
#       'href': 'https://api.spotify.com/v1/artists/0lJlKQvuM2Sd9DPPyUXcHg',
#       'id': '0lJlKQvuM2Sd9DPPyUXcHg',
#       'name': 'Sixpence None The Richer',
#       'type': 'artist',
#       'uri': 'spotify:artist:0lJlKQvuM2Sd9DPPyUXcHg'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 208680,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE19900312'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/229rA87dA2nRFuLrw7Bt1y'},
#     'href': 'https://api.spotify.com/v1/tracks/229rA87dA2nRFuLrw7Bt1y',
#     'id': '229rA87dA2nRFuLrw7Bt1y',
#     'is_local': False,
#     'name': 'Kiss Me',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:229rA87dA2nRFuLrw7Bt1y'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:57:40Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1l7ZsJRRS8wlW3WfJfPfNS'},
#        'href': 'https://api.spotify.com/v1/artists/1l7ZsJRRS8wlW3WfJfPfNS',
#        'id': '1l7ZsJRRS8wlW3WfJfPfNS',
#        'name': 'Christina Aguilera',
#        'type': 'artist',
#        'uri': 'spotify:artist:1l7ZsJRRS8wlW3WfJfPfNS'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/10uyvuWsvX8SSREpMrMYiJ'},
#      'href': 'https://api.spotify.com/v1/albums/10uyvuWsvX8SSREpMrMYiJ',
#      'id': '10uyvuWsvX8SSREpMrMYiJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27345b4d467e92c4786c805fada',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0245b4d467e92c4786c805fada',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485145b4d467e92c4786c805fada',
#        'width': 64}],
#      'name': 'Come On Over Baby/Genie In A Bottle',
#      'release_date': '2001-11-20',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:10uyvuWsvX8SSREpMrMYiJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1l7ZsJRRS8wlW3WfJfPfNS'},
#       'href': 'https://api.spotify.com/v1/artists/1l7ZsJRRS8wlW3WfJfPfNS',
#       'id': '1l7ZsJRRS8wlW3WfJfPfNS',
#       'name': 'Christina Aguilera',
#       'type': 'artist',
#       'uri': 'spotify:artist:1l7ZsJRRS8wlW3WfJfPfNS'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 217893,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC19900032'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4gW7mm93XKmqdPduQ3bpqS'},
#     'href': 'https://api.spotify.com/v1/tracks/4gW7mm93XKmqdPduQ3bpqS',
#     'id': '4gW7mm93XKmqdPduQ3bpqS',
#     'is_local': False,
#     'name': 'Genie In A Bottle (Album Version)',
#     'popularity': 10,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4gW7mm93XKmqdPduQ3bpqS'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:57:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4uN3DsfENc7dp0OLO0FEIb'},
#        'href': 'https://api.spotify.com/v1/artists/4uN3DsfENc7dp0OLO0FEIb',
#        'id': '4uN3DsfENc7dp0OLO0FEIb',
#        'name': 'Sugar Ray',
#        'type': 'artist',
#        'uri': 'spotify:artist:4uN3DsfENc7dp0OLO0FEIb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2hjQQj7x2YipViOCw6UX1N'},
#      'href': 'https://api.spotify.com/v1/albums/2hjQQj7x2YipViOCw6UX1N',
#      'id': '2hjQQj7x2YipViOCw6UX1N',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27377444909203d907c0c79027d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0277444909203d907c0c79027d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485177444909203d907c0c79027d',
#        'width': 64}],
#      'name': 'The Best Of Sugar Ray',
#      'release_date': '2005-06-17',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2hjQQj7x2YipViOCw6UX1N'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4uN3DsfENc7dp0OLO0FEIb'},
#       'href': 'https://api.spotify.com/v1/artists/4uN3DsfENc7dp0OLO0FEIb',
#       'id': '4uN3DsfENc7dp0OLO0FEIb',
#       'name': 'Sugar Ray',
#       'type': 'artist',
#       'uri': 'spotify:artist:4uN3DsfENc7dp0OLO0FEIb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 220200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT20503176'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Neq7tjnknt4URNI8txFL4'},
#     'href': 'https://api.spotify.com/v1/tracks/6Neq7tjnknt4URNI8txFL4',
#     'id': '6Neq7tjnknt4URNI8txFL4',
#     'is_local': False,
#     'name': 'Every Morning - Remastered',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8f44a10c7b279459343b2709f609c17aa78b2c3b?cid=3254c90a45084464a6d23b2466846bba',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:6Neq7tjnknt4URNI8txFL4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:58:08Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/601893mmW5hl1FBOykWZHG'},
#        'href': 'https://api.spotify.com/v1/artists/601893mmW5hl1FBOykWZHG',
#        'id': '601893mmW5hl1FBOykWZHG',
#        'name': 'Deborah Cox',
#        'type': 'artist',
#        'uri': 'spotify:artist:601893mmW5hl1FBOykWZHG'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/16FPcGpqQfcvqpCLvZsWWD'},
#      'href': 'https://api.spotify.com/v1/albums/16FPcGpqQfcvqpCLvZsWWD',
#      'id': '16FPcGpqQfcvqpCLvZsWWD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27392c79e319a1a5519ebf669d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0292c79e319a1a5519ebf669d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485192c79e319a1a5519ebf669d4',
#        'width': 64}],
#      'name': 'One Wish',
#      'release_date': '1998-09-17',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:16FPcGpqQfcvqpCLvZsWWD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/601893mmW5hl1FBOykWZHG'},
#       'href': 'https://api.spotify.com/v1/artists/601893mmW5hl1FBOykWZHG',
#       'id': '601893mmW5hl1FBOykWZHG',
#       'name': 'Deborah Cox',
#       'type': 'artist',
#       'uri': 'spotify:artist:601893mmW5hl1FBOykWZHG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 262333,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAR19800100'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/51QxenFmXlJXUN9mpvxlaL'},
#     'href': 'https://api.spotify.com/v1/tracks/51QxenFmXlJXUN9mpvxlaL',
#     'id': '51QxenFmXlJXUN9mpvxlaL',
#     'is_local': False,
#     'name': "Nobody's Supposed to Be Here",
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/10480540e1891b10d5f5c7c6896a8e495eb2f5ac?cid=3254c90a45084464a6d23b2466846bba',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:51QxenFmXlJXUN9mpvxlaL'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:58:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7slfeZO9LsJbWgpkIoXBUJ'},
#        'href': 'https://api.spotify.com/v1/artists/7slfeZO9LsJbWgpkIoXBUJ',
#        'id': '7slfeZO9LsJbWgpkIoXBUJ',
#        'name': 'Ricky Martin',
#        'type': 'artist',
#        'uri': 'spotify:artist:7slfeZO9LsJbWgpkIoXBUJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1k1Cr3nlJDa8pvwZUJ5xfj'},
#      'href': 'https://api.spotify.com/v1/albums/1k1Cr3nlJDa8pvwZUJ5xfj',
#      'id': '1k1Cr3nlJDa8pvwZUJ5xfj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e7e9b85cc1f021ec12130d80',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e7e9b85cc1f021ec12130d80',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e7e9b85cc1f021ec12130d80',
#        'width': 64}],
#      'name': 'Ricky Martin',
#      'release_date': '1999',
#      'release_date_precision': 'year',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1k1Cr3nlJDa8pvwZUJ5xfj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7slfeZO9LsJbWgpkIoXBUJ'},
#       'href': 'https://api.spotify.com/v1/artists/7slfeZO9LsJbWgpkIoXBUJ',
#       'id': '7slfeZO9LsJbWgpkIoXBUJ',
#       'name': 'Ricky Martin',
#       'type': 'artist',
#       'uri': 'spotify:artist:7slfeZO9LsJbWgpkIoXBUJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 243160,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLB639920005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Ph6L4l8dYUuXFmb71Ajnd'},
#     'href': 'https://api.spotify.com/v1/tracks/0Ph6L4l8dYUuXFmb71Ajnd',
#     'id': '0Ph6L4l8dYUuXFmb71Ajnd',
#     'is_local': False,
#     'name': "Livin' la Vida Loca",
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5fdf7aacfed97c3f3d476f58dac07b8214421acc?cid=3254c90a45084464a6d23b2466846bba',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0Ph6L4l8dYUuXFmb71Ajnd'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:58:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2S8UlyXW4JjjHcbeg8ddIo'},
#        'href': 'https://api.spotify.com/v1/artists/2S8UlyXW4JjjHcbeg8ddIo',
#        'id': '2S8UlyXW4JjjHcbeg8ddIo',
#        'name': '702',
#        'type': 'artist',
#        'uri': 'spotify:artist:2S8UlyXW4JjjHcbeg8ddIo'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6PELMehRtCwGXXyFS0fLKR'},
#      'href': 'https://api.spotify.com/v1/albums/6PELMehRtCwGXXyFS0fLKR',
#      'id': '6PELMehRtCwGXXyFS0fLKR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730100a4e7e46b63b46e03b158',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020100a4e7e46b63b46e03b158',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510100a4e7e46b63b46e03b158',
#        'width': 64}],
#      'name': '702',
#      'release_date': '1999-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6PELMehRtCwGXXyFS0fLKR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2S8UlyXW4JjjHcbeg8ddIo'},
#       'href': 'https://api.spotify.com/v1/artists/2S8UlyXW4JjjHcbeg8ddIo',
#       'id': '2S8UlyXW4JjjHcbeg8ddIo',
#       'name': '702',
#       'type': 'artist',
#       'uri': 'spotify:artist:2S8UlyXW4JjjHcbeg8ddIo'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 166693,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMO19984788'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4VSyH8AkIt3kaR5xIPFVVi'},
#     'href': 'https://api.spotify.com/v1/tracks/4VSyH8AkIt3kaR5xIPFVVi',
#     'id': '4VSyH8AkIt3kaR5xIPFVVi',
#     'is_local': False,
#     'name': 'Where My Girls At',
#     'popularity': 59,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4VSyH8AkIt3kaR5xIPFVVi'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:58:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2DlGxzQSjYe5N6G9nkYghR'},
#        'href': 'https://api.spotify.com/v1/artists/2DlGxzQSjYe5N6G9nkYghR',
#        'id': '2DlGxzQSjYe5N6G9nkYghR',
#        'name': 'Jennifer Lopez',
#        'type': 'artist',
#        'uri': 'spotify:artist:2DlGxzQSjYe5N6G9nkYghR'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/27n5XoBdAfUyfEHots85MG'},
#      'href': 'https://api.spotify.com/v1/albums/27n5XoBdAfUyfEHots85MG',
#      'id': '27n5XoBdAfUyfEHots85MG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273086243095865927a8ec603b0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02086243095865927a8ec603b0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851086243095865927a8ec603b0',
#        'width': 64}],
#      'name': 'On The 6',
#      'release_date': '1999-06-28',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:27n5XoBdAfUyfEHots85MG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2DlGxzQSjYe5N6G9nkYghR'},
#       'href': 'https://api.spotify.com/v1/artists/2DlGxzQSjYe5N6G9nkYghR',
#       'id': '2DlGxzQSjYe5N6G9nkYghR',
#       'name': 'Jennifer Lopez',
#       'type': 'artist',
#       'uri': 'spotify:artist:2DlGxzQSjYe5N6G9nkYghR'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 266000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19900608'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1EQgbMBc304Ss86dXBulJA'},
#     'href': 'https://api.spotify.com/v1/tracks/1EQgbMBc304Ss86dXBulJA',
#     'id': '1EQgbMBc304Ss86dXBulJA',
#     'is_local': False,
#     'name': 'If You Had My Love',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1EQgbMBc304Ss86dXBulJA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:58:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2sil8z5kiy4r76CRTXxBCA'},
#        'href': 'https://api.spotify.com/v1/artists/2sil8z5kiy4r76CRTXxBCA',
#        'id': '2sil8z5kiy4r76CRTXxBCA',
#        'name': 'The Goo Goo Dolls',
#        'type': 'artist',
#        'uri': 'spotify:artist:2sil8z5kiy4r76CRTXxBCA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4UMjBXcRqIgMZ1XumU2x5T'},
#      'href': 'https://api.spotify.com/v1/albums/4UMjBXcRqIgMZ1XumU2x5T',
#      'id': '4UMjBXcRqIgMZ1XumU2x5T',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eda9478c39a21e1cdc6609ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eda9478c39a21e1cdc6609ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eda9478c39a21e1cdc6609ca',
#        'width': 64}],
#      'name': 'Dizzy up the Girl',
#      'release_date': '1998-09-11',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4UMjBXcRqIgMZ1XumU2x5T'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2sil8z5kiy4r76CRTXxBCA'},
#       'href': 'https://api.spotify.com/v1/artists/2sil8z5kiy4r76CRTXxBCA',
#       'id': '2sil8z5kiy4r76CRTXxBCA',
#       'name': 'The Goo Goo Dolls',
#       'type': 'artist',
#       'uri': 'spotify:artist:2sil8z5kiy4r76CRTXxBCA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB19800781'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0nnwn7LWHCAu09jfuH1xTA'},
#     'href': 'https://api.spotify.com/v1/tracks/0nnwn7LWHCAu09jfuH1xTA',
#     'id': '0nnwn7LWHCAu09jfuH1xTA',
#     'is_local': False,
#     'name': 'Slide',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/28cc4f1970ab4dfa3ed97b98ce801e884584a321?cid=3254c90a45084464a6d23b2466846bba',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0nnwn7LWHCAu09jfuH1xTA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T05:59:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rSXSAkZ67PYJSvpUpkOr7'},
#        'href': 'https://api.spotify.com/v1/artists/5rSXSAkZ67PYJSvpUpkOr7',
#        'id': '5rSXSAkZ67PYJSvpUpkOr7',
#        'name': 'Backstreet Boys',
#        'type': 'artist',
#        'uri': 'spotify:artist:5rSXSAkZ67PYJSvpUpkOr7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ySxm9hxBNss01WCL7GLyQ'},
#      'href': 'https://api.spotify.com/v1/albums/5ySxm9hxBNss01WCL7GLyQ',
#      'id': '5ySxm9hxBNss01WCL7GLyQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732160c02bc56f192df0f4986b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022160c02bc56f192df0f4986b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512160c02bc56f192df0f4986b',
#        'width': 64}],
#      'name': 'Millennium',
#      'release_date': '1999-05-18',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5ySxm9hxBNss01WCL7GLyQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rSXSAkZ67PYJSvpUpkOr7'},
#       'href': 'https://api.spotify.com/v1/artists/5rSXSAkZ67PYJSvpUpkOr7',
#       'id': '5rSXSAkZ67PYJSvpUpkOr7',
#       'name': 'Backstreet Boys',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rSXSAkZ67PYJSvpUpkOr7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
# ...
#       'id': '2Ca9nb6MJ3lwyF7dRNJm3M',
#       'name': 'Citizen King',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Ca9nb6MJ3lwyF7dRNJm3M'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 207026,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB19801111'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/460Wn6Dq2uMviG5nPXtPnb'},
#     'href': 'https://api.spotify.com/v1/tracks/460Wn6Dq2uMviG5nPXtPnb',
#     'id': '460Wn6Dq2uMviG5nPXtPnb',
#     'is_local': False,
#     'name': 'Better Days (And the Bottom Drops Out)',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/08995a17996730d88efc94f653789d615654e9d9?cid=3254c90a45084464a6d23b2466846bba',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:460Wn6Dq2uMviG5nPXtPnb'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T06:25:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AR',
#       'AU',
#       'BO',
#       'BR',
#       'CL',
#       'CO',
#       'CR',
#       'DE',
#       'DO',
#       'EC',
#       'GT',
#       'HK',
#       'HN',
#       'ID',
#       'IN',
#       'MX',
#       'MY',
#       'NI',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PY',
#       'SG',
#       'SV',
#       'TH',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6cvclW19pbpe50eqWxQa6J'},
#      'href': 'https://api.spotify.com/v1/albums/6cvclW19pbpe50eqWxQa6J',
#      'id': '6cvclW19pbpe50eqWxQa6J',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273813d37ea1e98f4563f66c784',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02813d37ea1e98f4563f66c784',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851813d37ea1e98f4563f66c784',
#        'width': 64}],
#      'name': 'Music Of The Heart The Album',
#      'release_date': '1999-08-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6cvclW19pbpe50eqWxQa6J'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5IFCkqu9J6xdWeYMk5I889'},
#       'href': 'https://api.spotify.com/v1/artists/5IFCkqu9J6xdWeYMk5I889',
#       'id': '5IFCkqu9J6xdWeYMk5I889',
#       'name': 'Gloria Estefan',
#       'type': 'artist',
#       'uri': 'spotify:artist:5IFCkqu9J6xdWeYMk5I889'}],
#     'available_markets': ['AR',
#      'AU',
#      'BO',
#      'BR',
#      'CL',
#      'CO',
#      'CR',
#      'DE',
#      'DO',
#      'EC',
#      'GT',
#      'HK',
#      'HN',
#      'ID',
#      'IN',
#      'MX',
#      'MY',
#      'NI',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PY',
#      'SG',
#      'SV',
#      'TH',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 269866,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19901307'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/679kEY6AiqHRbKjsX7zhZN'},
#     'href': 'https://api.spotify.com/v1/tracks/679kEY6AiqHRbKjsX7zhZN',
#     'id': '679kEY6AiqHRbKjsX7zhZN',
#     'is_local': False,
#     'name': 'Music of My Heart',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/271acce79e6596b81fb90f8afabf3a787252a131?cid=3254c90a45084464a6d23b2466846bba',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:679kEY6AiqHRbKjsX7zhZN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T06:25:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5vngPClqofybhPERIqQMYd'},
#        'href': 'https://api.spotify.com/v1/artists/5vngPClqofybhPERIqQMYd',
#        'id': '5vngPClqofybhPERIqQMYd',
#        'name': 'George Strait',
#        'type': 'artist',
#        'uri': 'spotify:artist:5vngPClqofybhPERIqQMYd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Kudx2lMsMx3svYdb2xe2F'},
#      'href': 'https://api.spotify.com/v1/albums/2Kudx2lMsMx3svYdb2xe2F',
#      'id': '2Kudx2lMsMx3svYdb2xe2F',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27309b72b61970ed83b5d304e89',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0209b72b61970ed83b5d304e89',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485109b72b61970ed83b5d304e89',
#        'width': 64}],
#      'name': 'Always Never The Same',
#      'release_date': '1999-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:2Kudx2lMsMx3svYdb2xe2F'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5vngPClqofybhPERIqQMYd'},
#       'href': 'https://api.spotify.com/v1/artists/5vngPClqofybhPERIqQMYd',
#       'id': '5vngPClqofybhPERIqQMYd',
#       'name': 'George Strait',
#       'type': 'artist',
#       'uri': 'spotify:artist:5vngPClqofybhPERIqQMYd'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 219600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC19801464'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1TanmIWbaUj5NVwJ3k4XPd'},
#     'href': 'https://api.spotify.com/v1/tracks/1TanmIWbaUj5NVwJ3k4XPd',
#     'id': '1TanmIWbaUj5NVwJ3k4XPd',
#     'is_local': False,
#     'name': 'Write This Down',
#     'popularity': 66,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1TanmIWbaUj5NVwJ3k4XPd'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T06:25:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4iHNK0tOyZPYnBU7nGAgpQ'},
#        'href': 'https://api.spotify.com/v1/artists/4iHNK0tOyZPYnBU7nGAgpQ',
#        'id': '4iHNK0tOyZPYnBU7nGAgpQ',
#        'name': 'Mariah Carey',
#        'type': 'artist',
#        'uri': 'spotify:artist:4iHNK0tOyZPYnBU7nGAgpQ'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4gWPIB6d0O4LxfIIodAwkR'},
#      'href': 'https://api.spotify.com/v1/albums/4gWPIB6d0O4LxfIIodAwkR',
#      'id': '4gWPIB6d0O4LxfIIodAwkR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a2f89c03d1b7ecd5d51cba8a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a2f89c03d1b7ecd5d51cba8a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a2f89c03d1b7ecd5d51cba8a',
#        'width': 64}],
#      'name': "#1's",
#      'release_date': '1998-09-14',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:4gWPIB6d0O4LxfIIodAwkR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4iHNK0tOyZPYnBU7nGAgpQ'},
#       'href': 'https://api.spotify.com/v1/artists/4iHNK0tOyZPYnBU7nGAgpQ',
#       'id': '4iHNK0tOyZPYnBU7nGAgpQ',
#       'name': 'Mariah Carey',
#       'type': 'artist',
#       'uri': 'spotify:artist:4iHNK0tOyZPYnBU7nGAgpQ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#       'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#       'id': '6XpaIBNiVzIetEPCWDvAFP',
#       'name': 'Whitney Houston',
#       'type': 'artist',
#       'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 274466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19804755'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2izVExEYERUnsRr6mb840Q'},
#     'href': 'https://api.spotify.com/v1/tracks/2izVExEYERUnsRr6mb840Q',
#     'id': '2izVExEYERUnsRr6mb840Q',
#     'is_local': False,
#     'name': 'When You Believe (from The Prince of Egypt)',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2izVExEYERUnsRr6mb840Q'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2011-08-17T06:25:40Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'available_markets': ['AR',
#       'AT',
#       'BO',
#       'BR',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'DE',
#       'DO',
#       'EC',
#       'GT',
#       'HN',
#       'JP',
#       'LI',
#       'MX',
#       'NI',
#       'PA',
#       'PE',
#       'PY',
#       'SV',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0CADmCXbIx4F9m6TBwLtFd'},
#      'href': 'https://api.spotify.com/v1/albums/0CADmCXbIx4F9m6TBwLtFd',
#      'id': '0CADmCXbIx4F9m6TBwLtFd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273583ce664168dca88fdc1c4c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02583ce664168dca88fdc1c4c1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851583ce664168dca88fdc1c4c1',
#        'width': 64}],
#      'name': "'N Sync",
#      'release_date': '1997-05-26',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0CADmCXbIx4F9m6TBwLtFd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'available_markets': ['AR',
#      'AT',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'DE',
#      'DO',
#      'EC',
#      'GT',
#      'HN',
#      'JP',
#      'LI',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SV',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 282960,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEA819800192'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4mljNnZ2eaXKSbEAOzLlLE'},
#     'href': 'https://api.spotify.com/v1/tracks/4mljNnZ2eaXKSbEAOzLlLE',
#     'id': '4mljNnZ2eaXKSbEAOzLlLE',
#     'is_local': False,
#     'name': '(God Must Have Spent) A Little More Time On You',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f67dd5502068b0ec4bedd88904a2f0c59767ec3e?cid=3254c90a45084464a6d23b2466846bba',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4mljNnZ2eaXKSbEAOzLlLE'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 89}

# %%
top_99_df_items =json_normalize(top_99_data['items'])
# Out:
# <ipython-input-125-02b68ef32dd0>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   top_99_df_items =json_normalize(top_99_data['items'])

# %%
pd.set_option('display.max_columns', None)
top_99_df_items.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2011-08-17T05:56:25Z     False          None
# 1  2011-08-17T05:56:47Z     False          None
# 2  2011-08-17T05:57:07Z     False          None
# 3  2011-08-17T05:57:18Z     False          None
# 4  2011-08-17T05:57:29Z     False          None
#
#    added_by.external_urls.spotify                      added_by.href  \
# 0  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 1  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 2  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 3  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 4  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
#
#   added_by.id added_by.type   added_by.uri track.album.album_type  \
# 0                      user  spotify:user:                  album
# 1                      user  spotify:user:                  album
# 2                      user  spotify:user:            compilation
# 3                      user  spotify:user:                  album
# 4                      user  spotify:user:                  album
#
#                                  track.album.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                        track.album.available_markets  \
# 0  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 1  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                    track.album.external_urls.spotify  \
# 0  https://open.spotify.com/album/0jZfbz0dNfDjPSg...
# 1  https://open.spotify.com/album/1CvjjpvqVMoyprs...
# 2  https://open.spotify.com/album/4bXTYQ8nVBYO4k3...
# 3  https://open.spotify.com/album/7e2tD25UffSO101...
# 4  https://open.spotify.com/album/6HGNrA7twXCXBRQ...
#
#                                     track.album.href          track.album.id  \
# 0  https://api.spotify.com/v1/albums/0jZfbz0dNfDj...  0jZfbz0dNfDjPSg0hYJNth
# 1  https://api.spotify.com/v1/albums/1CvjjpvqVMoy...  1CvjjpvqVMoyprsf74bpYW
# 2  https://api.spotify.com/v1/albums/4bXTYQ8nVBYO...  4bXTYQ8nVBYO4k3C3TOVri
# 3  https://api.spotify.com/v1/albums/7e2tD25UffSO...  7e2tD25UffSO1019rrrRPe
# 4  https://api.spotify.com/v1/albums/6HGNrA7twXCX...  6HGNrA7twXCXBRQ2Rvc0kS
#
#                                   track.album.images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#             track.album.name track.album.release_date  \
# 0                    Believe                     1998
# 1                    Fanmail               1999-02-23
# 2  Whitney The Greatest Hits               2000-05-16
# 3         Baby One More Time               1999-01-12
# 4   Sixpence None The Richer                     1997
#
#   track.album.release_date_precision  track.album.total_tracks  \
# 0                               year                        10
# 1                                day                        17
# 2                                day                        36
# 3                                day                        11
# 4                               year                        13
#
#   track.album.type                       track.album.uri  \
# 0            album  spotify:album:0jZfbz0dNfDjPSg0hYJNth
# 1            album  spotify:album:1CvjjpvqVMoyprsf74bpYW
# 2            album  spotify:album:4bXTYQ8nVBYO4k3C3TOVri
# 3            album  spotify:album:7e2tD25UffSO1019rrrRPe
# 4            album  spotify:album:6HGNrA7twXCXBRQ2Rvc0kS
#
#                                        track.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                              track.available_markets  track.disc_number  \
# 0  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...                  1
# 1  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...                  1
# 2                                                 []                  1
# 3                                                 []                  1
# 4                                                 []                  1
#
#    track.duration_ms  track.episode  track.explicit track.external_ids.isrc  \
# 0             239026          False           False            GBAHT9803002
# 1             214400          False           False            USLF29900479
# 2             245266          False           False            USAR19800139
# 3             210706          False           False            USJI19810404
# 4             208680          False           False            USEE19900312
#
#                          track.external_urls.spotify  \
# 0  https://open.spotify.com/track/2goLsvvODILDzee...
# 1  https://open.spotify.com/track/1KGi9sZVMeszgZO...
# 2  https://open.spotify.com/track/3EIzVtVW78E6qJq...
# 3  https://open.spotify.com/track/7KIfxh9R4sxkPkn...
# 4  https://open.spotify.com/track/229rA87dA2nRFuL...
#
#                                           track.href                track.id  \
# 0  https://api.spotify.com/v1/tracks/2goLsvvODILD...  2goLsvvODILDzeeiT4dAoR
# 1  https://api.spotify.com/v1/tracks/1KGi9sZVMesz...  1KGi9sZVMeszgZOWivFpxs
# 2  https://api.spotify.com/v1/tracks/3EIzVtVW78E6...  3EIzVtVW78E6qJqYTa0WUx
# 3  https://api.spotify.com/v1/tracks/7KIfxh9R4sxk...  7KIfxh9R4sxkPkn19ikdGd
# 4  https://api.spotify.com/v1/tracks/229rA87dA2nR...  229rA87dA2nRFuLrw7Bt1y
#
#    track.is_local                                         track.name  \
# 0           False                                            Believe
# 1           False                                          No Scrubs
# 2           False  Heartbreak Hotel (feat. Faith Evans & Kelly Pr...
# 3           False                              ...Baby One More Time
# 4           False                                            Kiss Me
#
#    track.popularity                                  track.preview_url  \
# 0                75  https://p.scdn.co/mp3-preview/579967c91dc409b6...
# 1                78  https://p.scdn.co/mp3-preview/69daa711bddd8fe7...
# 2                 0                                               None
# 3                 0                                               None
# 4                 0                                               None
#
#    track.track  track.track_number track.type  \
# 0         True                   1      track
# 1         True                   5      track
# 2         True                  15      track
# 3         True                   1      track
# 4         True                   4      track
#
#                               track.uri video_thumbnail.url
# 0  spotify:track:2goLsvvODILDzeeiT4dAoR                None
# 1  spotify:track:1KGi9sZVMeszgZOWivFpxs                None
# 2  spotify:track:3EIzVtVW78E6qJqYTa0WUx                None
# 3  spotify:track:7KIfxh9R4sxkPkn19ikdGd                None
# 4  spotify:track:229rA87dA2nRFuLrw7Bt1y                None

# %%
top_99_df_items.shape
# Out:
# (89, 40)

# %%
top_99_data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Cher'

# %%
artists = []
for i in top_99_data['items']:
    artists.append(i['track']['artists'][0]['name'])

top_99_df_items['artists'] = artists

# %%
top_99_df_items = top_99_df_items[['track.album.album_type',
       'track.album.id', 'track.album.name',
       'track.album.release_date',
       'track.album.total_tracks', 'track.album.type','track.duration_ms', 'track.explicit',
       'track.id', 'track.name', 'artists']]
top_99_df_items
# Out:
#    track.album.album_type          track.album.id  \
# 0                   album  0jZfbz0dNfDjPSg0hYJNth
# 1                   album  1CvjjpvqVMoyprsf74bpYW
# 2             compilation  4bXTYQ8nVBYO4k3C3TOVri
# 3                   album  7e2tD25UffSO1019rrrRPe
# 4                   album  6HGNrA7twXCXBRQ2Rvc0kS
# ..                    ...                     ...
# 84                  album  74T4OTGbvmJWobgc4ABtMq
# 85            compilation  6cvclW19pbpe50eqWxQa6J
# 86                  album  2Kudx2lMsMx3svYdb2xe2F
# 87            compilation  4gWPIB6d0O4LxfIIodAwkR
# 88                  album  0CADmCXbIx4F9m6TBwLtFd
#
#                 track.album.name track.album.release_date  \
# 0                        Believe                     1998
# 1                        Fanmail               1999-02-23
# 2      Whitney The Greatest Hits               2000-05-16
# 3             Baby One More Time               1999-01-12
# 4       Sixpence None The Richer                     1997
# ..                           ...                      ...
# 84                Mobile Estates               1999-02-26
# 85  Music Of The Heart The Album               1999-08-01
# 86         Always Never The Same               1999-01-01
# 87                          #1's               1998-09-14
# 88                       'N Sync               1997-05-26
#
#     track.album.total_tracks track.album.type  track.duration_ms  \
# 0                         10            album             239026
# 1                         17            album             214400
# 2                         36            album             245266
# 3                         11            album             210706
# 4                         13            album             208680
# ..                       ...              ...                ...
# 84                        13            album             207026
# 85                        12            album             269866
# 86                        10            album             219600
# 87                        17            album             274466
# 88                        13            album             282960
#
#     track.explicit                track.id  \
# 0            False  2goLsvvODILDzeeiT4dAoR
# 1            False  1KGi9sZVMeszgZOWivFpxs
# 2            False  3EIzVtVW78E6qJqYTa0WUx
# 3            False  7KIfxh9R4sxkPkn19ikdGd
# 4            False  229rA87dA2nRFuLrw7Bt1y
# ..             ...                     ...
# 84           False  460Wn6Dq2uMviG5nPXtPnb
# 85           False  679kEY6AiqHRbKjsX7zhZN
# 86           False  1TanmIWbaUj5NVwJ3k4XPd
# 87           False  2izVExEYERUnsRr6mb840Q
# 88           False  4mljNnZ2eaXKSbEAOzLlLE
#
#                                            track.name  \
# 0                                             Believe
# 1                                           No Scrubs
# 2   Heartbreak Hotel (feat. Faith Evans & Kelly Pr...
# 3                               ...Baby One More Time
# 4                                             Kiss Me
# ..                                                ...
# 84             Better Days (And the Bottom Drops Out)
# 85                                  Music of My Heart
# 86                                    Write This Down
# 87        When You Believe (from The Prince of Egypt)
# 88    (God Must Have Spent) A Little More Time On You
#
#                      artists
# 0                       Cher
# 1                        TLC
# 2            Whitney Houston
# 3             Britney Spears
# 4   Sixpence None The Richer
# ..                       ...
# 84              Citizen King
# 85                    *NSYNC
# 86             George Strait
# 87              Mariah Carey
# 88                    *NSYNC
#
# [89 rows x 11 columns]

# %%
billboard_file = "billboard.csv"
billboard_df = pd.read_csv(billboard_file, encoding="ISO-8859-1")
# Out:
# C:\Users\Michael\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (1,2,6,7,8,9,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
billboard_df.shape
# Out:
# (97225, 12)

# %%
# 1. Create Spotify table
# 2. Join Spotify and Billboard tables
